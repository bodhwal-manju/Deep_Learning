# %% [markdown]
# # **Implementation of ANN using Keras:**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import os

# %% [markdown]
# # Creating a simple Classifier using keras on MNIST data

# %%
mnist=tf.keras.datasets.mnist

# %%
mnist
# Out:
# <module 'keras.api._v2.keras.datasets.mnist' from '/usr/local/lib/python3.10/dist-packages/keras/api/_v2/keras/datasets/mnist/__init__.py'>

# %%
(X_train_full,y_train_full),(X_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train_full.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train_full[0].shape
# Out:
# (28, 28)

# %%
print(f"data type of X_train_full: {X_train_full.dtype},\n shape of X_train_full: {X_train_full.shape}")
# Out:
# data type of X_train_full: uint8,
#  shape of X_train_full: (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
## Create a validation data set from the full training data
## scale the data between 0 and 1 by dividing it by 255. as its an unsigned data between 0-255 range
X_valid ,X_train=X_train_full[:5000]/255.,X_train_full[5000:]/255.
y_valid ,y_train=y_train_full[:5000],y_train_full[5000:]

# %%
# scale the X_test as well
X_test=X_test/255.

# %%
# Train-55000
# Test-10000
# Val-5000

# %%
len(X_train_full[5000:])
# Out:
# 55000

# %%
# lets view some data
plt.imshow(X_train[0],cmap='binary')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(X_train[0],annot=True,cmap='binary')
# Out:
# <Axes: >

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dropout

# %%
# Creating Layers Of ANN

LAYERS=[tf.keras.layers.Flatten(input_shape=[28,28],name='inputLayer'),
        tf.keras.layers.Dense(300,activation='relu',name='hiddenLayer1',kernel_regularizer=regularizers.L2(1e-4)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(100,activation='relu',name='hiddenLayer2'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10,activation='softmax',name='outputLayer')]

model_clf=tf.keras.models.Sequential(LAYERS)

# %% [markdown]
# ## Method 2

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten

# define the model
model=Sequential()
model.add(Flatten(input_shape=[28,28],name='inputLayer'))
model.add(Dense(units=64,activation='relu',kernel_regularizer=regularizers.L2(1e-4)))
model.add(Dropout(0.2))
model.add(Dense(units=32,activation='relu',kernel_regularizer=regularizers.L1L2(l1=1e-5,l2=1e-4)))
model.add(Dropout(0.2))
model.add(Dense(units=10,activation='softmax'))

# %% [markdown]
# 784*64+64

# %%
784*64+64
# Out:
# 50240

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputLayer (Flatten)        (None, 784)               0
#
#  dense (Dense)               (None, 64)                50240
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 52650 (205.66 KB)
# Trainable params: 52650 (205.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
LOSS_FUNCTION ='sparse_categorical_crossentropy' # use=> tf.losses.sparse_categorical_crossentropy
OPTIMIZER='SGD' # or use with custom learning rate =>tf.keras.optimizers.SGD(0.02)
METRICS=['accuracy']

model.compile(loss=LOSS_FUNCTION,
              optimizer=OPTIMIZER,
              metrics=METRICS)

# %%
# training
EPOCHS=5
VALIDATION_SET=(X_valid,y_valid)
history =model.fit(X_train,y_train,epochs=EPOCHS,
                   validation_data=VALIDATION_SET,batch_size=32)
# Out:
# Epoch 1/5
# 1719/1719 [==============================] - 9s 5ms/step - loss: 1.0298 - accuracy: 0.6763 - val_loss: 0.4151 - val_accuracy: 0.8966
# Epoch 2/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.5317 - accuracy: 0.8483 - val_loss: 0.3093 - val_accuracy: 0.9210
# Epoch 3/5
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.4427 - accuracy: 0.8755 - val_loss: 0.2672 - val_accuracy: 0.9322
# Epoch 4/5
# 1719/1719 [==============================] - 4s 3ms/step - loss: 0.3878 - accuracy: 0.8946 - val_loss: 0.2442 - val_accuracy: 0.9356
# Epoch 5/5
# 1719/1719 [==============================] - 6s 3ms/step - loss: 0.3564 - accuracy: 0.9023 - val_loss: 0.2231 - val_accuracy: 0.9422

# %%
pd.DataFrame(history.history)
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.029783  0.676327  0.415084        0.8966
# 1  0.531724  0.848273  0.309343        0.9210
# 2  0.442678  0.875527  0.267201        0.9322
# 3  0.387782  0.894582  0.244241        0.9356
# 4  0.356431  0.902345  0.223144        0.9422

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >
